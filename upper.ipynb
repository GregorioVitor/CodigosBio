# %%
from Bio import SeqIO

# %%
arq = "/home/gregorio/Área de Trabalho/Linux/Interface/Arquivos/G._max_PLncDB.fa"

# %%
for seq_record in SeqIO.parse(arq, "fasta"):
    print(seq_record.id)
# Out:
# GMAX_LNC000001.1
# GMAX_LNC000002.1
# GMAX_LNC000003.1
# GMAX_LNC000004.1
# GMAX_LNC000005.1
# GMAX_LNC000006.1
# GMAX_LNC000007.1
# GMAX_LNC000008.1
# GMAX_LNC000009.1
# GMAX_LNC000010.1
# GMAX_LNC000011.1
# GMAX_LNC000012.1
# GMAX_LNC000013.1
# GMAX_LNC000014.1
# GMAX_LNC000015.1
# GMAX_LNC000016.1
# GMAX_LNC000016.2
# GMAX_LNC000017.1
# GMAX_LNC000018.1
# GMAX_LNC000018.2
# GMAX_LNC000019.1
# GMAX_LNC000020.1
# GMAX_LNC000021.1
# GMAX_LNC000022.1
# GMAX_LNC000023.1
# GMAX_LNC000024.1
# GMAX_LNC000025.1
# GMAX_LNC000026.1
# GMAX_LNC000027.1
# GMAX_LNC000028.1
# GMAX_LNC000029.1
# GMAX_LNC000030.1
# GMAX_LNC000031.1
# GMAX_LNC000032.1
# GMAX_LNC000033.1
# GMAX_LNC000034.1
# GMAX_LNC000035.1
# GMAX_LNC000036.1
# GMAX_LNC000037.1
# GMAX_LNC000038.1
# GMAX_LNC000039.1
# GMAX_LNC000040.1
# GMAX_LNC000041.1
# GMAX_LNC000042.1
# GMAX_LNC000043.1
# GMAX_LNC000044.1
# GMAX_LNC000045.1
# GMAX_LNC000046.1
# GMAX_LNC000047.1
# GMAX_LNC000048.1
# GMAX_LNC000049.1
# GMAX_LNC000050.1
# ...

# %%
for seq_record in SeqIO.parse(arq, "fasta"):
    seq_record.seq.upper()
